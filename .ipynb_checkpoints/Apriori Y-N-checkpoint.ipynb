# %% [markdown]
# # Association rule mining with Apriori algorithm

# %%
import numpy as np
import pandas as pd
import re
from efficient_apriori import apriori

# %%
size = 50

# %% [markdown]
# ## Data preparation

# %%
colnames = ["class_name","handicapped_infants","water_project_cost_sharing","adoption_of_the_budget_resolution",
            "physician_fee_freeze","el_salvador_aid","religious_groups_in_schools","anti_satellite_test_ban",
            "aid_to_nicaraguan_contras","mx_missile","immigration","synfuels_corporation_cutback",
            "education_spending","superfund_right_to_sue","crime","duty_free_exports",
            "export_administration_act_south_africa"]

data = pd.read_csv("/home/laura/Scrivania/KDMproj/house-votes-84.txt", sep = ',',na_values = '?', header = None, 
                   names = colnames)
data = pd.DataFrame(data)

data["republican"] = 0
data.loc[data.class_name=="republican","republican"] = pd.Series(np.ones(len(data.class_name=="republican"),dtype=int))
del data["class_name"]
del colnames[0]

data.head()
# Out:
#   handicapped_infants water_project_cost_sharing  \
# 0                   n                          y
# 1                   n                          y
# 2                 NaN                          y
# 3                   n                          y
# 4                   y                          y
#
#   adoption_of_the_budget_resolution physician_fee_freeze el_salvador_aid  \
# 0                                 n                    y               y
# 1                                 n                    y               y
# 2                                 y                  NaN               y
# 3                                 y                    n             NaN
# 4                                 y                    n               y
#
#   religious_groups_in_schools anti_satellite_test_ban  \
# 0                           y                       n
# 1                           y                       n
# 2                           y                       n
# 3                           y                       n
# 4                           y                       n
#
#   aid_to_nicaraguan_contras mx_missile immigration  \
# 0                         n          n           y
# 1                         n          n           n
# 2                         n          n           n
# 3                         n          n           n
# 4                         n          n           n
#
#   synfuels_corporation_cutback education_spending superfund_right_to_sue  \
# 0                          NaN                  y                      y
# 1                            n                  y                      y
# 2                            y                  n                      y
# 3                            y                  n                      y
# 4                            y                NaN                      y
#
#   crime duty_free_exports export_administration_act_south_africa  republican
# 0     y                 n                                      y           1
# 1     y                 n                                    NaN           1
# 2     y                 n                                      n           0
# 3     n                 n                                      y           0
# 4     y                 y                                      y           0

# %%
data = data.iloc[:size,]

# %%
transactions = []
for i in range(len(data)):
    t = []
    for j in range(len(data.columns)-1):
        if data.iloc[i,j] == "y":
            t.append(data.columns[j]+"_yes")
        if data.iloc[i,j] == "n":
            t.append(data.columns[j]+"_no")
    if data.iloc[i,16] == 1:
        t.append("republican")
    if data.iloc[i,16] == 0:
        t.append("democrat")
    transactions.append(t)

# %% [markdown]
# ## Association rule extraction

# %%
itemset, rules = apriori(transactions, min_support=0.2, min_confidence=1)

# %%
clean_rules = []
for rule in rules:
    s=str(rule)
    s=re.sub(" \(.*", "", s)
    s=re.sub("{", "", s)
    s=re.sub("}", "", s)
    s=s.split(" -> ")
    for i, sub in enumerate(s):
        s[i] = set(sub.split(", "))
    clean_rules.append(s)

# %%
print(len(clean_rules))
# Out:
# 576193

# %%
min_cons = []
for rule in clean_rules:
    if len(rule[1]) == 1:
        min_cons.append(rule)

min_pred = []
min_rules = []
for rule in min_cons:
    is_minimal = True
    for p in min_pred:
        if p < rule[0]:
            is_minimal = False
    if is_minimal:
        min_pred.append(rule[0])
        min_rules.append(rule)

print("\n{} minimal rules found \n".format(len(minimal_rules)))
# Out:
# 161 minimal rules founded

# %%
minimal_rules
# Out:
# [[{'adoption_of_the_budget_resolution_no'}, {'el_salvador_aid_yes'}],
#  [{'physician_fee_freeze_yes'}, {'adoption_of_the_budget_resolution_no'}],
#  [{'adoption_of_the_budget_resolution_no'}, {'physician_fee_freeze_yes'}],
#  [{'republican'}, {'adoption_of_the_budget_resolution_no'}],
#  [{'crime_no'}, {'adoption_of_the_budget_resolution_yes'}],
#  [{'adoption_of_the_budget_resolution_yes'}, {'democrat'}],
#  [{'el_salvador_aid_no'}, {'adoption_of_the_budget_resolution_yes'}],
#  [{'physician_fee_freeze_no'}, {'adoption_of_the_budget_resolution_yes'}],
#  [{'superfund_right_to_sue_no'}, {'adoption_of_the_budget_resolution_yes'}],
#  [{'aid_to_nicaraguan_contras_no'}, {'anti_satellite_test_ban_no'}],
#  [{'aid_to_nicaraguan_contras_no'}, {'mx_missile_no'}],
#  [{'anti_satellite_test_ban_yes'}, {'aid_to_nicaraguan_contras_yes'}],
#  [{'el_salvador_aid_no'}, {'aid_to_nicaraguan_contras_yes'}],
#  [{'mx_missile_yes'}, {'aid_to_nicaraguan_contras_yes'}],
#  [{'superfund_right_to_sue_no'}, {'aid_to_nicaraguan_contras_yes'}],
#  [{'mx_missile_yes'}, {'anti_satellite_test_ban_yes'}],
#  [{'superfund_right_to_sue_no'}, {'anti_satellite_test_ban_yes'}],
#  [{'crime_no'}, {'democrat'}],
#  [{'crime_no'}, {'physician_fee_freeze_no'}],
#  [{'duty_free_exports_yes'}, {'democrat'}],
#  [{'el_salvador_aid_no'}, {'democrat'}],
#  [{'physician_fee_freeze_no'}, {'democrat'}],
#  [{'superfund_right_to_sue_no'}, {'democrat'}],
#  [{'education_spending_yes'}, {'duty_free_exports_no'}],
#  [{'el_salvador_aid_no'}, {'physician_fee_freeze_no'}],
#  [{'superfund_right_to_sue_no'}, {'el_salvador_aid_no'}],
#  [{'physician_fee_freeze_yes'}, {'el_salvador_aid_yes'}],
#  [{'republican'}, {'el_salvador_aid_yes'}],
#  [{'superfund_right_to_sue_no'}, {'handicapped_infants_yes'}],
#  [{'mx_missile_yes'}, {'religious_groups_in_schools_no'}],
#  [{'superfund_right_to_sue_no'}, {'physician_fee_freeze_no'}],
#  [{'republican'}, {'physician_fee_freeze_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'democrat'},
#   {'adoption_of_the_budget_resolution_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'education_spending_no'},
#   {'adoption_of_the_budget_resolution_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'synfuels_corporation_cutback_yes'},
#   {'adoption_of_the_budget_resolution_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'water_project_cost_sharing_yes'},
#   {'adoption_of_the_budget_resolution_yes'}],
#  [{'democrat', 'handicapped_infants_yes'},
#   {'adoption_of_the_budget_resolution_yes'}],
#  [{'democrat', 'religious_groups_in_schools_no'},
#   {'adoption_of_the_budget_resolution_yes'}],
#  [{'democrat', 'synfuels_corporation_cutback_yes'},
#   {'adoption_of_the_budget_resolution_yes'}],
#  [{'education_spending_no', 'religious_groups_in_schools_no'},
#   {'adoption_of_the_budget_resolution_yes'}],
#  [{'education_spending_no', 'synfuels_corporation_cutback_yes'},
#   {'adoption_of_the_budget_resolution_yes'}],
#  [{'handicapped_infants_yes', 'synfuels_corporation_cutback_yes'},
#   {'adoption_of_the_budget_resolution_yes'}],
#  [{'anti_satellite_test_ban_no', 'crime_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'anti_satellite_test_ban_no', 'el_salvador_aid_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'anti_satellite_test_ban_no', 'handicapped_infants_no'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'anti_satellite_test_ban_no', 'immigration_no'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'anti_satellite_test_ban_no', 'mx_missile_no'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'anti_satellite_test_ban_no', 'superfund_right_to_sue_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'anti_satellite_test_ban_no', 'synfuels_corporation_cutback_no'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'anti_satellite_test_ban_no', 'water_project_cost_sharing_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'crime_yes', 'handicapped_infants_no'}, {'aid_to_nicaraguan_contras_no'}],
#  [{'crime_yes', 'religious_groups_in_schools_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'duty_free_exports_no', 'handicapped_infants_no'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'el_salvador_aid_yes', 'handicapped_infants_no'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'el_salvador_aid_yes', 'mx_missile_no'}, {'aid_to_nicaraguan_contras_no'}],
#  [{'el_salvador_aid_yes', 'religious_groups_in_schools_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'el_salvador_aid_yes', 'water_project_cost_sharing_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'handicapped_infants_no', 'mx_missile_no'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'handicapped_infants_no', 'religious_groups_in_schools_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'immigration_no', 'religious_groups_in_schools_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'mx_missile_no', 'religious_groups_in_schools_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'mx_missile_no', 'superfund_right_to_sue_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'religious_groups_in_schools_yes', 'superfund_right_to_sue_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'religious_groups_in_schools_yes', 'synfuels_corporation_cutback_no'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'aid_to_nicaraguan_contras_yes', 'education_spending_no'},
#   {'anti_satellite_test_ban_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'immigration_no'},
#   {'anti_satellite_test_ban_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'religious_groups_in_schools_no'},
#   {'anti_satellite_test_ban_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'synfuels_corporation_cutback_no'},
#   {'anti_satellite_test_ban_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'water_project_cost_sharing_yes'},
#   {'anti_satellite_test_ban_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'synfuels_corporation_cutback_yes'},
#   {'crime_no'}],
#  [{'aid_to_nicaraguan_contras_yes', 'education_spending_no'}, {'democrat'}],
#  [{'aid_to_nicaraguan_contras_yes', 'democrat'}, {'el_salvador_aid_no'}],
#  [{'aid_to_nicaraguan_contras_yes', 'democrat'}, {'physician_fee_freeze_no'}],
#  [{'democrat', 'religious_groups_in_schools_no'},
#   {'aid_to_nicaraguan_contras_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'synfuels_corporation_cutback_yes'},
#   {'democrat'}],
#  [{'aid_to_nicaraguan_contras_yes', 'water_project_cost_sharing_yes'},
#   {'democrat'}],
#  [{'aid_to_nicaraguan_contras_yes', 'education_spending_no'},
#   {'el_salvador_aid_no'}],
#  [{'aid_to_nicaraguan_contras_yes', 'education_spending_no'},
#   {'physician_fee_freeze_no'}],
#  [{'education_spending_no', 'religious_groups_in_schools_no'},
#   {'aid_to_nicaraguan_contras_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'synfuels_corporation_cutback_yes'},
#   {'el_salvador_aid_no'}],
#  [{'aid_to_nicaraguan_contras_yes', 'water_project_cost_sharing_yes'},
#   {'el_salvador_aid_no'}],
#  [{'aid_to_nicaraguan_contras_yes',
#    'export_administration_act_south_africa_yes'},
#   {'handicapped_infants_yes'}],
#  [{'export_administration_act_south_africa_yes',
#    'religious_groups_in_schools_no'},
#   {'aid_to_nicaraguan_contras_yes'}],
#  [{'handicapped_infants_yes', 'religious_groups_in_schools_no'},
#   {'aid_to_nicaraguan_contras_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'synfuels_corporation_cutback_yes'},
#   {'handicapped_infants_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'synfuels_corporation_cutback_yes'},
#   {'physician_fee_freeze_no'}],
#  [{'aid_to_nicaraguan_contras_yes', 'water_project_cost_sharing_yes'},
#   {'physician_fee_freeze_no'}],
#  [{'religious_groups_in_schools_no', 'synfuels_corporation_cutback_no'},
#   {'aid_to_nicaraguan_contras_yes'}],
#  [{'aid_to_nicaraguan_contras_yes', 'synfuels_corporation_cutback_no'},
#   {'religious_groups_in_schools_no'}],
#  [{'anti_satellite_test_ban_no', 'crime_yes'}, {'el_salvador_aid_yes'}],
#  [{'crime_yes', 'handicapped_infants_no'}, {'anti_satellite_test_ban_no'}],
#  [{'anti_satellite_test_ban_no', 'crime_yes'}, {'mx_missile_no'}],
#  [{'crime_yes', 'religious_groups_in_schools_yes'},
#   {'anti_satellite_test_ban_no'}],
#  [{'duty_free_exports_no', 'handicapped_infants_no'},
#   {'anti_satellite_test_ban_no'}],
#  [{'duty_free_exports_no', 'religious_groups_in_schools_yes'},
#   {'anti_satellite_test_ban_no'}],
#  [{'el_salvador_aid_yes', 'handicapped_infants_no'},
#   {'anti_satellite_test_ban_no'}],
#  [{'el_salvador_aid_yes', 'mx_missile_no'}, {'anti_satellite_test_ban_no'}],
#  [{'anti_satellite_test_ban_no', 'el_salvador_aid_yes'}, {'mx_missile_no'}],
#  [{'el_salvador_aid_yes', 'religious_groups_in_schools_yes'},
#   {'anti_satellite_test_ban_no'}],
#  [{'anti_satellite_test_ban_no', 'synfuels_corporation_cutback_no'},
#   {'el_salvador_aid_yes'}],
#  [{'el_salvador_aid_yes', 'water_project_cost_sharing_yes'},
#   {'anti_satellite_test_ban_no'}],
#  [{'export_administration_act_south_africa_yes',
#    'religious_groups_in_schools_yes'},
#   {'anti_satellite_test_ban_no'}],
#  [{'anti_satellite_test_ban_no', 'export_administration_act_south_africa_yes'},
#   {'religious_groups_in_schools_yes'}],
#  [{'handicapped_infants_no', 'mx_missile_no'}, {'anti_satellite_test_ban_no'}],
#  [{'anti_satellite_test_ban_no', 'handicapped_infants_no'}, {'mx_missile_no'}],
#  [{'handicapped_infants_no', 'religious_groups_in_schools_yes'},
#   {'anti_satellite_test_ban_no'}],
#  [{'anti_satellite_test_ban_no', 'immigration_no'}, {'mx_missile_no'}],
#  [{'immigration_no', 'religious_groups_in_schools_yes'},
#   {'anti_satellite_test_ban_no'}],
#  [{'mx_missile_no', 'religious_groups_in_schools_yes'},
#   {'anti_satellite_test_ban_no'}],
#  [{'mx_missile_no', 'superfund_right_to_sue_yes'},
#   {'anti_satellite_test_ban_no'}],
#  [{'anti_satellite_test_ban_no', 'superfund_right_to_sue_yes'},
#   {'mx_missile_no'}],
#  [{'anti_satellite_test_ban_no', 'synfuels_corporation_cutback_no'},
#   {'mx_missile_no'}],
#  [{'anti_satellite_test_ban_no', 'water_project_cost_sharing_yes'},
#   {'mx_missile_no'}],
#  [{'religious_groups_in_schools_yes', 'superfund_right_to_sue_yes'},
#   {'anti_satellite_test_ban_no'}],
#  [{'religious_groups_in_schools_yes', 'synfuels_corporation_cutback_no'},
#   {'anti_satellite_test_ban_no'}],
#  [{'anti_satellite_test_ban_no', 'synfuels_corporation_cutback_no'},
#   {'religious_groups_in_schools_yes'}],
#  [{'democrat', 'religious_groups_in_schools_no'},
#   {'anti_satellite_test_ban_yes'}],
#  [{'education_spending_no', 'religious_groups_in_schools_no'},
#   {'anti_satellite_test_ban_yes'}],
#  [{'export_administration_act_south_africa_yes',
#    'religious_groups_in_schools_no'},
#   {'anti_satellite_test_ban_yes'}],
#  [{'handicapped_infants_yes', 'religious_groups_in_schools_no'},
#   {'anti_satellite_test_ban_yes'}],
#  [{'religious_groups_in_schools_no', 'synfuels_corporation_cutback_no'},
#   {'anti_satellite_test_ban_yes'}],
#  [{'el_salvador_aid_yes', 'export_administration_act_south_africa_yes'},
#   {'crime_yes'}],
#  [{'crime_yes', 'handicapped_infants_no'}, {'el_salvador_aid_yes'}],
#  [{'crime_yes', 'religious_groups_in_schools_yes'}, {'el_salvador_aid_yes'}],
#  [{'crime_yes', 'superfund_right_to_sue_yes'}, {'el_salvador_aid_yes'}],
#  [{'crime_yes', 'handicapped_infants_no'}, {'mx_missile_no'}],
#  [{'crime_yes', 'religious_groups_in_schools_yes'}, {'mx_missile_no'}],
#  [{'crime_yes', 'water_project_cost_sharing_yes'}, {'mx_missile_no'}],
#  [{'education_spending_no', 'religious_groups_in_schools_no'}, {'democrat'}],
#  [{'education_spending_no', 'synfuels_corporation_cutback_yes'}, {'democrat'}],
#  [{'democrat', 'religious_groups_in_schools_no'}, {'el_salvador_aid_no'}],
#  [{'democrat', 'handicapped_infants_yes'}, {'physician_fee_freeze_no'}],
#  [{'handicapped_infants_yes', 'synfuels_corporation_cutback_yes'},
#   {'democrat'}],
#  [{'democrat', 'religious_groups_in_schools_no'}, {'physician_fee_freeze_no'}],
#  [{'duty_free_exports_no', 'handicapped_infants_no'}, {'mx_missile_no'}],
#  [{'education_spending_no', 'religious_groups_in_schools_no'},
#   {'el_salvador_aid_no'}],
#  [{'education_spending_no', 'religious_groups_in_schools_no'},
#   {'physician_fee_freeze_no'}],
#  [{'el_salvador_aid_yes', 'handicapped_infants_no'}, {'mx_missile_no'}],
#  [{'el_salvador_aid_yes', 'religious_groups_in_schools_yes'},
#   {'mx_missile_no'}],
#  [{'el_salvador_aid_yes', 'water_project_cost_sharing_yes'},
#   {'mx_missile_no'}],
#  [{'religious_groups_in_schools_yes', 'synfuels_corporation_cutback_no'},
#   {'el_salvador_aid_yes'}],
#  [{'export_administration_act_south_africa_yes',
#    'religious_groups_in_schools_no'},
#   {'handicapped_infants_yes'}],
#  [{'handicapped_infants_no', 'religious_groups_in_schools_yes'},
#   {'mx_missile_no'}],
#  [{'handicapped_infants_yes', 'synfuels_corporation_cutback_yes'},
#   {'physician_fee_freeze_no'}],
#  [{'immigration_no', 'religious_groups_in_schools_yes'}, {'mx_missile_no'}],
#  [{'religious_groups_in_schools_yes', 'superfund_right_to_sue_yes'},
#   {'mx_missile_no'}],
#  [{'religious_groups_in_schools_yes', 'synfuels_corporation_cutback_no'},
#   {'mx_missile_no'}],
#  [{'duty_free_exports_no',
#    'el_salvador_aid_yes',
#    'synfuels_corporation_cutback_no'},
#   {'adoption_of_the_budget_resolution_no'}],
#  [{'duty_free_exports_no',
#    'superfund_right_to_sue_yes',
#    'synfuels_corporation_cutback_no'},
#   {'adoption_of_the_budget_resolution_no'}],
#  [{'duty_free_exports_no',
#    'superfund_right_to_sue_yes',
#    'water_project_cost_sharing_yes'},
#   {'aid_to_nicaraguan_contras_no'}],
#  [{'duty_free_exports_no',
#    'superfund_right_to_sue_yes',
#    'water_project_cost_sharing_yes'},
#   {'anti_satellite_test_ban_no'}],
#  [{'el_salvador_aid_yes', 'immigration_no', 'superfund_right_to_sue_yes'},
#   {'crime_yes'}],
#  [{'democrat',
#    'synfuels_corporation_cutback_no',
#    'water_project_cost_sharing_yes'},
#   {'education_spending_no'}],
#  [{'duty_free_exports_no',
#    'el_salvador_aid_yes',
#    'synfuels_corporation_cutback_no'},
#   {'physician_fee_freeze_yes'}],
#  [{'duty_free_exports_no',
#    'el_salvador_aid_yes',
#    'synfuels_corporation_cutback_no'},
#   {'republican'}],
#  [{'duty_free_exports_no',
#    'superfund_right_to_sue_yes',
#    'synfuels_corporation_cutback_no'},
#   {'el_salvador_aid_yes'}],
#  [{'duty_free_exports_no',
#    'superfund_right_to_sue_yes',
#    'water_project_cost_sharing_yes'},
#   {'mx_missile_no'}],
#  [{'duty_free_exports_no',
#    'superfund_right_to_sue_yes',
#    'synfuels_corporation_cutback_no'},
#   {'physician_fee_freeze_yes'}],
#  [{'duty_free_exports_no',
#    'superfund_right_to_sue_yes',
#    'synfuels_corporation_cutback_no'},
#   {'republican'}],
#  [{'export_administration_act_south_africa_yes',
#    'immigration_no',
#    'mx_missile_no'},
#   {'water_project_cost_sharing_yes'}],
#  [{'crime_yes',
#    'duty_free_exports_no',
#    'el_salvador_aid_yes',
#    'immigration_no'},
#   {'superfund_right_to_sue_yes'}]]
